# %%
# Hi everyone.
# We're going to explore the NYPD data set to figure out who in NYC is the naughtiest group :o
# First, let's import some stuff!
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns

# %%
df = pd.read_csv('NYPD_Data/NYPD_Complaint_Data_Historic_20240221.csv')
# Out:
# C:\Users\TimEW\AppData\Local\Temp\ipykernel_14536\3630547272.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('NYPD_Data/NYPD_Complaint_Data_Historic_20240221.csv')

# %%
df.head(50)
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0    16784525   06/17/2006     00:30:00          NaN       (null)
# 1    10973318   04/06/2006     09:30:00          NaN       (null)
# 2    23859785   08/12/2006     11:29:00          NaN       (null)
# 3    16544671   05/22/2006     16:30:00          NaN       (null)
# 4    16856905   06/01/2005     00:01:00   06/18/2006     11:00:00
# 5    16705935   04/06/2006     09:00:00   05/04/2006     23:59:00
# 6    33015364   06/08/2007     03:46:00          NaN       (null)
# 7    27287587   03/07/2007     16:10:00          NaN       (null)
# 8    34082558   08/30/2007     02:25:00          NaN       (null)
# 9    26081232   01/03/2007     16:35:00          NaN       (null)
# 10   26877794   02/13/2007     15:31:00          NaN       (null)
# 11   55140091   12/22/2008     15:45:00          NaN       (null)
# 12   48549600   07/23/2008     11:25:00          NaN       (null)
# 13   51631469   09/24/2008     09:31:00          NaN       (null)
# 14   47212909   06/12/2008     14:50:00          NaN       (null)
# 15   50105458   08/14/2008     09:22:00          NaN       (null)
# 16   37570080   01/07/2008     09:09:00          NaN       (null)
# 17   54186569   11/18/2008     14:50:00          NaN       (null)
# 18   55564799   01/09/2009     12:00:00          NaN       (null)
# 19   66327584   09/26/2009     23:30:00          NaN       (null)
# 20   61375862   05/02/2009     08:46:00          NaN       (null)
# 21   63607094   07/09/2009     23:00:00          NaN       (null)
# 22   64527516   08/08/2009     04:30:00          NaN       (null)
# 23   71083735   02/01/2010     10:23:00          NaN       (null)
# 24   73429513   06/28/2010     17:39:00          NaN       (null)
# 25   75863810   12/02/2010     11:32:00          NaN       (null)
# 26   75317824   10/27/2010     19:30:00          NaN       (null)
# 27   81557241   11/03/2011     20:34:00          NaN       (null)
# 28   79730877   07/09/2011     02:04:00          NaN       (null)
# 29   78183120   04/09/2011     20:00:00          NaN       (null)
# 30   80669174   09/10/2011     15:20:00          NaN       (null)
# 31   79609538   07/02/2011     19:35:00          NaN       (null)
# 32   78373268   04/20/2011     10:00:00          NaN       (null)
# 33   79184462   06/07/2011     10:25:00          NaN       (null)
# 34   81658780   11/10/2011     18:45:00          NaN       (null)
# 35   76765312   01/09/2011     15:17:00          NaN       (null)
# 36   83352328   02/24/2012     14:50:00          NaN       (null)
# 37   86582455   09/04/2012     11:00:00          NaN       (null)
# 38   82453219   01/03/2012     12:44:00          NaN       (null)
# 39   87457913   10/28/2012     00:57:00          NaN       (null)
# 40   86648612   09/06/2012     17:00:00          NaN       (null)
# 41   83855877   03/24/2012     11:35:00          NaN       (null)
# 42   84401076   11/24/2011     18:00:00          NaN       (null)
# 43   85749206   07/12/2012     18:00:00          NaN       (null)
# 44   91501083   07/06/2013     02:28:00          NaN       (null)
# 45   91688313   07/18/2013     00:05:00          NaN       (null)
# 46   90763108   05/21/2013     15:00:00          NaN       (null)
# 47   92817791   09/27/2013     19:50:00          NaN       (null)
# 48   90622425   05/13/2013     17:15:00          NaN       (null)
# 49   88888098   01/27/2013     20:00:00          NaN       (null)
#
#     ADDR_PCT_CD      RPT_DT  KY_CD                     OFNS_DESC  PD_CD  ...  \
# 0           6.0  06/18/2006    578                 HARRASSMENT 2  638.0  ...
# 1           6.0  04/12/2006    578                 HARRASSMENT 2  638.0  ...
# 2          20.0  08/12/2006    105                       ROBBERY  361.0  ...
# 3          47.0  05/22/2006    105                       ROBBERY  380.0  ...
# 4           NaN  06/21/2006    104                          RAPE  153.0  ...
# 5           NaN  06/06/2006    341                 PETIT LARCENY  303.0  ...
# 6          68.0  07/09/2007    114                         ARSON  263.0  ...
# 7          14.0  03/07/2007    105                       ROBBERY  361.0  ...
# 8          18.0  08/30/2007    109                 GRAND LARCENY  415.0  ...
# 9          19.0  01/03/2007    105                       ROBBERY  361.0  ...
# 10         45.0  02/13/2007    105                       ROBBERY  361.0  ...
# 11          1.0  12/22/2008    105                       ROBBERY  361.0  ...
# 12         20.0  07/23/2008    105                       ROBBERY  361.0  ...
# 13         26.0  09/24/2008    105                       ROBBERY  361.0  ...
# 14         79.0  06/12/2008    105                       ROBBERY  361.0  ...
# 15         44.0  08/14/2008    105                       ROBBERY  361.0  ...
# 16         47.0  01/07/2008    114                         ARSON  263.0  ...
# 17         47.0  11/18/2008    105                       ROBBERY  389.0  ...
# 18         68.0  01/09/2009    105                       ROBBERY  361.0  ...
# 19         13.0  09/27/2009    344  ASSAULT 3 & RELATED OFFENSES  101.0  ...
# 20         34.0  05/02/2009    105                       ROBBERY  380.0  ...
# 21         28.0  07/09/2009    126       MISCELLANEOUS PENAL LAW  198.0  ...
# 22         44.0  08/08/2009    105                       ROBBERY  361.0  ...
# 23         13.0  02/01/2010    105                       ROBBERY  361.0  ...
# 24         32.0  06/28/2010    105                       ROBBERY  366.0  ...
# 25         90.0  12/03/2010    114                         ARSON  263.0  ...
# 26         40.0  10/28/2010    341                 PETIT LARCENY  321.0  ...
# 27         60.0  11/04/2011    114                         ARSON  263.0  ...
# 28         68.0  07/09/2011    104                          RAPE  159.0  ...
# 29         68.0  04/10/2011    344  ASSAULT 3 & RELATED OFFENSES  101.0  ...
# 30          9.0  09/10/2011    109                 GRAND LARCENY  419.0  ...
# 31          9.0  07/02/2011    578                 HARRASSMENT 2  638.0  ...
# 32         32.0  04/22/2011    106                FELONY ASSAULT  109.0  ...
# 33         77.0  06/07/2011    105                       ROBBERY  361.0  ...
# 34         42.0  11/10/2011    106                FELONY ASSAULT  109.0  ...
# 35         47.0  01/09/2011    114                         ARSON  263.0  ...
# 36         33.0  02/24/2012    105                       ROBBERY  361.0  ...
# 37         13.0  09/04/2012    105                       ROBBERY  361.0  ...
# 38         77.0  01/03/2012    105                       ROBBERY  361.0  ...
# 39         25.0  10/28/2012    105                       ROBBERY  360.0  ...
# 40         32.0  09/07/2012    106                FELONY ASSAULT  105.0  ...
# 41         40.0  03/24/2012    105                       ROBBERY  375.0  ...
# 42         47.0  02/21/2012    104                          RAPE  157.0  ...
# 43         47.0  07/14/2012    104                          RAPE  157.0  ...
# 44        121.0  07/06/2013    360                        (null)  661.0  ...
# 45         84.0  07/18/2013    105                       ROBBERY  366.0  ...
# 46         88.0  05/21/2013    578                 HARRASSMENT 2  638.0  ...
# 47         84.0  09/27/2013    578                 HARRASSMENT 2  638.0  ...
# 48         14.0  05/13/2013    344  ASSAULT 3 & RELATED OFFENSES  101.0  ...
# 49         79.0  01/29/2013    104                          RAPE  153.0  ...
#
#    SUSP_SEX TRANSIT_DISTRICT   Latitude  Longitude  \
# 0         F              NaN  40.734091 -74.006238
# 1         F              NaN  40.741288 -74.006167
# 2         M              NaN  40.775083 -73.982182
# 3         M              NaN  40.903862 -73.846994
# 4         M              NaN        NaN        NaN
# 5    (null)              NaN        NaN        NaN
# 6    (null)              NaN  40.635178 -74.024779
# 7         M              NaN  40.755640 -73.990952
# 8         M              NaN  40.760405 -73.987474
# 9         M              NaN  40.763744 -73.964984
# 10        M              NaN  40.841254 -73.843330
# 11        M              NaN  40.722407 -73.999333
# 12        M              NaN  40.785471 -73.978768
# 13        M              NaN  40.804498 -73.966458
# 14        M              NaN  40.680151 -73.945124
# 15   (null)              NaN  40.827377 -73.924495
# 16   (null)              NaN  40.878477 -73.854551
# 17        M              NaN  40.875756 -73.835718
# 18        M              NaN  40.613118 -74.033405
# 19        U              NaN  40.741970 -73.980859
# 20   (null)              NaN  40.849288 -73.938936
# 21        F              NaN  40.805726 -73.954414
# 22        M              NaN  40.823281 -73.923923
# 23        M              NaN  40.740763 -73.998074
# 24   (null)              NaN  40.816002 -73.941332
# 25   (null)              NaN  40.705448 -73.951809
# 26   (null)              NaN  40.811507 -73.922606
# 27        U              NaN  40.576157 -73.975984
# 28   (null)              NaN  40.638865 -74.022712
# 29        U              NaN  40.631688 -74.021735
# 30        M              NaN  40.731644 -73.988383
# 31        U              NaN  40.725192 -73.987044
# 32        F              NaN  40.817591 -73.938313
# 33        M              NaN  40.669789 -73.949116
# 34        M              NaN  40.826180 -73.909737
# 35   (null)              NaN  40.894743 -73.841515
# 36        M              NaN  40.834995 -73.944197
# 37        M              NaN  40.737387 -73.979723
# 38        M              NaN  40.670391 -73.956621
# 39        M              NaN  40.804715 -73.938227
# 40        M              NaN  40.812739 -73.937618
# 41        M              NaN  40.814856 -73.919899
# 42        M              NaN  40.887314 -73.847272
# 43        M              NaN  40.887314 -73.847272
# 44        M              NaN  40.607190 -74.162421
# 45        M              NaN  40.686728 -73.990466
# 46        M              NaN  40.683605 -73.967425
# 47        M              NaN  40.692256 -73.987742
# 48        F              NaN  40.755461 -73.981552
# 49        M              NaN  40.689001 -73.945027
#
#                                   Lat_Lon              PATROL_BORO  \
# 0                 (40.734091, -74.006238)    PATROL BORO MAN SOUTH
# 1                 (40.741288, -74.006167)    PATROL BORO MAN SOUTH
# 2                 (40.775083, -73.982182)    PATROL BORO MAN NORTH
# 3                 (40.903862, -73.846994)        PATROL BORO BRONX
# 4                                     NaN                   (null)
# 5                                     NaN                   (null)
# 6                 (40.635178, -74.024779)  PATROL BORO BKLYN SOUTH
# 7                  (40.75564, -73.990952)    PATROL BORO MAN SOUTH
# 8             (40.76040496, -73.98747426)    PATROL BORO MAN SOUTH
# 9                 (40.763744, -73.964984)    PATROL BORO MAN NORTH
# 10                 (40.841254, -73.84333)        PATROL BORO BRONX
# 11                (40.722407, -73.999333)    PATROL BORO MAN SOUTH
# 12                (40.785471, -73.978768)    PATROL BORO MAN NORTH
# 13                (40.804498, -73.966458)    PATROL BORO MAN NORTH
# 14                (40.680151, -73.945124)  PATROL BORO BKLYN NORTH
# 15                (40.827377, -73.924495)        PATROL BORO BRONX
# 16                (40.878477, -73.854551)        PATROL BORO BRONX
# 17            (40.87575627, -73.83571847)        PATROL BORO BRONX
# 18                (40.613118, -74.033405)  PATROL BORO BKLYN SOUTH
# 19            (40.74197032, -73.98085932)    PATROL BORO MAN SOUTH
# 20            (40.84928836, -73.93893585)    PATROL BORO MAN NORTH
# 21            (40.80572591, -73.95441428)    PATROL BORO MAN NORTH
# 22                (40.823281, -73.923923)        PATROL BORO BRONX
# 23                (40.740763, -73.998074)    PATROL BORO MAN SOUTH
# 24                (40.816002, -73.941332)    PATROL BORO MAN NORTH
# 25                (40.705448, -73.951809)  PATROL BORO BKLYN NORTH
# 26                (40.811507, -73.922606)        PATROL BORO BRONX
# 27            (40.57615688, -73.97598385)  PATROL BORO BKLYN SOUTH
# 28  (40.6388651705916, -74.0227120876572)  PATROL BORO BKLYN SOUTH
# 29            (40.63168773, -74.02173545)  PATROL BORO BKLYN SOUTH
# 30                (40.731644, -73.988383)    PATROL BORO MAN SOUTH
# 31             (40.7251925, -73.98704433)    PATROL BORO MAN SOUTH
# 32                (40.817591, -73.938313)    PATROL BORO MAN NORTH
# 33                (40.669789, -73.949116)  PATROL BORO BKLYN NORTH
# 34                 (40.82618, -73.909737)        PATROL BORO BRONX
# 35                (40.894743, -73.841515)        PATROL BORO BRONX
# 36                (40.834995, -73.944197)    PATROL BORO MAN NORTH
# 37                (40.737387, -73.979723)    PATROL BORO MAN SOUTH
# 38                (40.670391, -73.956621)  PATROL BORO BKLYN NORTH
# 39                (40.804715, -73.938227)    PATROL BORO MAN NORTH
# 40            (40.81273905, -73.93761828)    PATROL BORO MAN NORTH
# 41                (40.814856, -73.919899)        PATROL BORO BRONX
# 42  (40.8873136344706, -73.8472717577564)        PATROL BORO BRONX
# 43  (40.8873136344706, -73.8472717577564)        PATROL BORO BRONX
# 44            (40.60719029, -74.16242136)                   (null)
# 45            (40.68672771, -73.99046643)  PATROL BORO BKLYN NORTH
# 46                (40.683605, -73.967425)  PATROL BORO BKLYN NORTH
# 47                (40.692256, -73.987742)  PATROL BORO BKLYN NORTH
# 48                (40.755461, -73.981552)    PATROL BORO MAN SOUTH
# 49    (40.68900139556, -73.9450265328727)  PATROL BORO BKLYN NORTH
#
#    STATION_NAME  VIC_AGE_GROUP        VIC_RACE VIC_SEX
# 0        (null)          45-64           WHITE       F
# 1        (null)          45-64           WHITE       F
# 2        (null)         (null)         UNKNOWN       D
# 3        (null)          25-44           WHITE       M
# 4        (null)            <18           BLACK       F
# 5        (null)            65+           WHITE       F
# 6        (null)         (null)         UNKNOWN       E
# 7        (null)         (null)         UNKNOWN       D
# 8        (null)          25-44           BLACK       F
# 9        (null)         (null)         UNKNOWN       D
# 10       (null)        UNKNOWN         UNKNOWN       D
# 11       (null)         (null)         UNKNOWN       D
# 12       (null)         (null)         UNKNOWN       D
# 13       (null)         (null)         UNKNOWN       D
# 14       (null)         (null)         UNKNOWN       D
# 15       (null)         (null)         UNKNOWN       D
# 16       (null)         (null)         UNKNOWN       E
# 17       (null)            <18           BLACK       M
# 18       (null)         (null)         UNKNOWN       D
# 19       (null)          25-44           WHITE       M
# 20       (null)          18-24           WHITE       F
# 21       (null)          25-44           BLACK       M
# 22       (null)          45-64           BLACK       M
# 23       (null)         (null)         UNKNOWN       D
# 24       (null)            <18           BLACK       M
# 25       (null)         (null)         UNKNOWN       E
# 26       (null)          45-64         UNKNOWN       F
# 27       (null)         (null)         UNKNOWN       E
# 28       (null)          25-44  WHITE HISPANIC       F
# 29       (null)            <18  WHITE HISPANIC       F
# 30       (null)          18-24           WHITE       F
# 31       (null)          45-64           WHITE       M
# 32       (null)          25-44           BLACK       F
# 33       (null)         (null)         UNKNOWN       D
# 34       (null)          18-24           BLACK       M
# 35       (null)         (null)         UNKNOWN       E
# 36       (null)         (null)         UNKNOWN       D
# 37       (null)         (null)         UNKNOWN       D
# 38       (null)         (null)         UNKNOWN       D
# 39       (null)          18-24           BLACK       M
# 40       (null)          18-24           BLACK       F
# 41       (null)         (null)         UNKNOWN       D
# 42       (null)          25-44           BLACK       F
# 43       (null)            <18           BLACK       F
# 44       (null)          25-44           WHITE       F
# 45       (null)          25-44           WHITE       M
# 46       (null)          18-24           BLACK       F
# 47       (null)          45-64           BLACK       F
# 48       (null)          25-44           WHITE       M
# 49       (null)            <18           BLACK       F
#
# [50 rows x 35 columns]

# %%
df.OFNS_DESC.unique()
# Out:
# array(['HARRASSMENT 2', 'ROBBERY', 'RAPE', 'PETIT LARCENY', 'ARSON',
#        'GRAND LARCENY', 'ASSAULT 3 & RELATED OFFENSES',
#        'MISCELLANEOUS PENAL LAW', 'FELONY ASSAULT', '(null)', 'FRAUDS',
#        'FORGERY', 'DANGEROUS DRUGS', 'BURGLARY', 'DANGEROUS WEAPONS',
#        'POSSESSION OF STOLEN PROPERTY', 'MURDER & NON-NEGL. MANSLAUGHTER',
#        'CRIMINAL MISCHIEF & RELATED OF', 'OFF. AGNST PUB ORD SENSBLTY &',
#        'OFFENSES AGAINST THE PERSON', 'VEHICLE AND TRAFFIC LAWS',
#        'INTOXICATED & IMPAIRED DRIVING', 'GRAND LARCENY OF MOTOR VEHICLE',
#        'OFFENSES AGAINST PUBLIC ADMINI', 'NYS LAWS-UNCLASSIFIED FELONY',
#        'THEFT-FRAUD', 'UNAUTHORIZED USE OF A VEHICLE',
#        'CRIMINAL TRESPASS', 'ADMINISTRATIVE CODE',
#        'OFFENSES INVOLVING FRAUD', 'KIDNAPPING & RELATED OFFENSES',
#        'SEX CRIMES', 'OFFENSES AGAINST PUBLIC SAFETY', 'OTHER STATE LAWS',
#        'ALCOHOLIC BEVERAGE CONTROL LAW', "BURGLAR'S TOOLS",
#        'PETIT LARCENY OF MOTOR VEHICLE',
#        'PROSTITUTION & RELATED OFFENSES', 'FRAUDULENT ACCOSTING',
#        'OTHER OFFENSES RELATED TO THEF', 'OFFENSES RELATED TO CHILDREN',
#        'JOSTLING', 'OTHER STATE LAWS (NON PENAL LA', 'GAMBLING',
#        'DISRUPTION OF A RELIGIOUS SERV', 'CHILD ABANDONMENT/NON SUPPORT',
#        'ANTICIPATORY OFFENSES', 'NEW YORK CITY HEALTH CODE', 'ESCAPE 3',
#        'ENDAN WELFARE INCOMP', 'FORTUNE TELLING',
#        'HOMICIDE-NEGLIGENT,UNCLASSIFIE', 'LOITERING/GAMBLING (CARDS, DIC',
#        'LOITERING FOR DRUG PURPOSES', 'UNLAWFUL POSS. WEAP. ON SCHOOL',
#        'HOMICIDE-NEGLIGENT-VEHICLE', 'LOITERING', 'LOITERING/DEVIATE SEX',
#        'ADMINISTRATIVE CODES', 'INTOXICATED/IMPAIRED DRIVING', 'ABORTION',
#        'THEFT OF SERVICES', 'OTHER TRAFFIC INFRACTION',
#        'DISORDERLY CONDUCT', 'OFFENSES AGAINST MARRIAGE UNCL',
#        'UNDER THE INFLUENCE OF DRUGS', 'OTHER STATE LAWS (NON PENAL LAW)',
#        'KIDNAPPING', 'AGRICULTURE & MRKTS LAW-UNCLASSIFIED',
#        'KIDNAPPING AND RELATED OFFENSES',
#        'NYS LAWS-UNCLASSIFIED VIOLATION', 'FELONY SEX CRIMES',
#        'CANNABIS RELATED OFFENSES'], dtype=object)

# %%
df.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'ADDR_PCT_CD', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD',
#        'PD_DESC', 'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'BORO_NM',
#        'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'JURIS_DESC', 'JURISDICTION_CODE',
#        'PARKS_NM', 'HADEVELOPT', 'HOUSING_PSA', 'X_COORD_CD', 'Y_COORD_CD',
#        'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT',
#        'Latitude', 'Longitude', 'Lat_Lon', 'PATROL_BORO', 'STATION_NAME',
#        'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX'],
#       dtype='object')

# %%
ax2 = sns.countplot(x='VIC_RACE', data=df, legend='brief')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\TimEW\AppData\Local\Temp\ipykernel_14536\1907456573.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=40, ha="right")

# %%
ax = sns.countplot(x='SUSP_RACE', data=df, legend='brief')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\TimEW\AppData\Local\Temp\ipykernel_14536\3544368141.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

# %%
df.describe()
# Out:
#         ADDR_PCT_CD         KY_CD         PD_CD  JURISDICTION_CODE  \
# count  8.359020e+06  8.359721e+06  8.352514e+06       8.359721e+06
# mean   6.332978e+01  2.970528e+02  4.120531e+02       6.936230e-01
# std    3.456075e+01  1.517021e+02  2.174988e+02       6.564904e+00
# min    1.000000e+00  1.010000e+02  1.000000e+02       0.000000e+00
# 25%    4.000000e+01  1.170000e+02  2.540000e+02       0.000000e+00
# 50%    6.300000e+01  3.410000e+02  3.610000e+02       0.000000e+00
# 75%    9.400000e+01  3.510000e+02  6.370000e+02       0.000000e+00
# max    1.230000e+02  8.810000e+02  9.750000e+02       9.700000e+01
#
#          X_COORD_CD    Y_COORD_CD  TRANSIT_DISTRICT      Latitude  \
# count  8.359267e+06  8.359267e+06     183312.000000  8.359267e+06
# mean   1.004909e+06  2.071661e+05         13.672045  4.073521e+01
# std    2.149792e+04  3.038138e+04         12.498551  9.349108e-02
# min    0.000000e+00  0.000000e+00          1.000000  0.000000e+00
# 25%    9.917000e+05  1.844870e+05          3.000000  4.067299e+01
# 50%    1.004377e+06  2.061740e+05         11.000000  4.073255e+01
# 75%    1.016802e+06  2.351530e+05         30.000000  4.081211e+01
# max    1.067306e+06  2.719090e+05         34.000000  4.091296e+01
#
#           Longitude
# count  8.359267e+06
# mean  -7.392534e+01
# std    1.089978e-01
# min   -7.425495e+01
# 25%   -7.397310e+01
# 50%   -7.392732e+01
# 75%   -7.388242e+01
# max    0.000000e+00

# %%
df.OFNS_DESC.value_counts()
# Out:
# OFNS_DESC
# PETIT LARCENY                      1446865
# HARRASSMENT 2                      1103392
# ASSAULT 3 & RELATED OFFENSES        877008
# CRIMINAL MISCHIEF & RELATED OF      834329
# GRAND LARCENY                       733005
#                                     ...
# FORTUNE TELLING                         12
# ABORTION                                 7
# OFFENSES AGAINST MARRIAGE UNCL           5
# UNDER THE INFLUENCE OF DRUGS             3
# KIDNAPPING AND RELATED OFFENSES          3
# Name: count, Length: 73, dtype: int64

# %%
ax3 = sns.countplot(x='OFNS_DESC', data=df, legend='brief')
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=40, ha="right")
plt.rcParams["figure.figsize"] = (3,1)
plt.show()
# Out:
# C:\Users\TimEW\AppData\Local\Temp\ipykernel_14536\551247422.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax3.set_xticklabels(ax3.get_xticklabels(), rotation=40, ha="right")
